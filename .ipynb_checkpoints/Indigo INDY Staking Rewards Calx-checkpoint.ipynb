# %%
# ========================================Staking DATA=================================================================

# %%
import os
import pandas as pd
import time
from datetime import datetime
from typing import Final
import glob

REF_DATE: Final[datetime] = datetime(2022, 11, 27)
EPOCH: Final[int] = 379

def get_difference(date: datetime) -> int:
    difference = date - REF_DATE

    return difference.days

path: str = os.getcwd() + "\\Staking_Data"
# path: str = os.getcwd() + "\\test"
# print(path)

if "Staking_Data_Cleaned" not in os.listdir(os.getcwd()):
    os.mkdir(f"{os.getcwd()}\\Staking_Data_Cleaned")

timestamps: list[int] = []
days = []

for filename in os.listdir(path):
    
#     print(filename)
    filename = filename.replace(".", "-")
    fname: list[str] = filename.split("-")
    timestamps.append(int(fname[-2]))

for timestamp in timestamps:
    full_date = time.strftime("%d %b %Y", time.gmtime(timestamp))
    date = pd.to_datetime(full_date)
    diff = get_difference(date)
    days.append(diff)

for index, file in list(enumerate(os.listdir(path))):
    df = pd.read_csv(f"{path}\\{file}")

    df.insert(0, column="epoch", value= 379 + (days[index])//5 )
    df.to_csv(f"{os.getcwd()}\\Staking_Data_Cleaned\\{timestamps[index]}.csv")
#     print(file)

# # Get CSV files list from a folder
path1 = "Staking_Data_Cleaned"
csv_files = glob.glob(path1 + "/*.csv")

# Read each CSV file into DataFrame
# This creates a list of dataframes
df_list1 = (pd.read_csv(file) for file in csv_files)
# Concatenate all DataFrames
staking_df   = pd.concat(df_list1, ignore_index=True)
staking_df.insert(4, column="Actual_INDY_Staked", value=staking_df['indy_staked']/1000000)
staking_df=staking_df.drop("Unnamed: 0",axis=1)
columns_to_drop = ['owner']

# Drop the specified columns
dk = staking_df.drop(columns=columns_to_drop).groupby('epoch').sum()
dk=dk.reset_index()
print(dk.to_string())
# Out:
#      epoch    indy_staked  Actual_INDY_Staked
# 0      380   252235251858        2.522353e+05
# 1      381   338183054489        3.381831e+05
# 2      382   403064633504        4.030646e+05
# 3      383   430959309830        4.309593e+05
# 4      384   448986900680        4.489869e+05
# 5      385   502047226284        5.020472e+05
# 6      386   547405830558        5.474058e+05
# 7      387   614138594820        6.141386e+05
# 8      388   719188684531        7.191887e+05
# 9      389   804093171625        8.040932e+05
# 10     390   808820233225        8.088202e+05
# 11     391   794981320706        7.949813e+05
# 12     392  1206552094010        1.206552e+06
# 13     393  1068295334343        1.068295e+06
# 14     394  1058979515326        1.058980e+06
# 15     395  1096453450490        1.096453e+06
# 16     396  1155370340182        1.155370e+06
# 17     397  1192872517599        1.192873e+06
# 18     398  1252471612464        1.252472e+06
# 19     399   707311526785        7.073115e+05
# 20     400   673395530527        6.733955e+05
# 21     401   698381673332        6.983817e+05
# 22     402   697214771939        6.972148e+05
# 23     403   845514396598        8.455144e+05
# 24     404  1631752272399        1.631752e+06
# 25     405  1966444111831        1.966444e+06
# 26     406  1948096310253        1.948096e+06
# 27     407  1945432601609        1.945433e+06
# 28     408  1935147271002        1.935147e+06
# 29     409  1953135579855        1.953136e+06
# 30     410  2161753374197        2.161753e+06
# 31     411  2191244740292        2.191245e+06
# 32     412  2282284503714        2.282285e+06
# 33     413  2468671697300        2.468672e+06
# 34     414  2590328353882        2.590328e+06
# 35     415  2550210374275        2.550210e+06
# 36     416  2646603619838        2.646604e+06
# 37     417  2646395085909        2.646395e+06
# 38     418  3073650984416        3.073651e+06
# 39     419  3063095091570        3.063095e+06
# 40     420  3056640975708        3.056641e+06
# 41     421  3043288473339        3.043288e+06
# 42     422  3209714436535        3.209714e+06
# 43     423  3151565028549        3.151565e+06
# 44     424  2750119816371        2.750120e+06
# 45     425  2728959118885        2.728959e+06
# 46     426  3006444722095        3.006445e+06
# 47     427  3114769012812        3.114769e+06
# 48     428  3289772049220        3.289772e+06
# 49     429  1880038329376        1.880038e+06
# 50     430  1884529058216        1.884529e+06
# 51     431  1886217831746        1.886218e+06
# 52     432  1796375717382        1.796376e+06
# 53     433  1906128787941        1.906129e+06
# 54     434  1986140043681        1.986140e+06
# 55     435  1991700149027        1.991700e+06
# 56     436  1871618948697        1.871619e+06
# 57     437  1889518450118        1.889518e+06
# 58     438  1892843183476        1.892843e+06
# 59     439  2155518682355        2.155519e+06
# 60     440  3954733883533        3.954734e+06
# 61     441  3979580820483        3.979581e+06
# 62     442  4028448095268        4.028448e+06
# 63     443  4129035526843        4.129036e+06
# 64     444  4113108535453        4.113109e+06
# 65     445  4424801001452        4.424801e+06
# 66     446  4682508652022        4.682509e+06
# 67     447  4760111521443        4.760112e+06
# 68     448  4755199869137        4.755200e+06
# 69     449  4755431126291        4.755431e+06
# 70     450  4778037779439        4.778038e+06
# 71     451  4983631785603        4.983632e+06
# 72     452  5048280848338        5.048281e+06
# 73     453  4993611853909        4.993612e+06
# 74     454  4982045954818        4.982046e+06
# 75     455  4961260101868        4.961260e+06
# 76     456  5134543772467        5.134544e+06
# 77     457  5149085889914        5.149086e+06
# 78     458  5033944138539        5.033944e+06
# 79     459  5186580612521        5.186581e+06
# 80     460  5189139465690        5.189139e+06
# 81     461  5141274386010        5.141274e+06
# 82     462  5147977136854        5.147977e+06
# 83     463  5159421488954        5.159421e+06
# 84     464  4987841723225        4.987842e+06
# 85     465  5604228819463        5.604229e+06
# 86     466  5716061852993        5.716062e+06
# 87     467  5725683693627        5.725684e+06
# 88     468  5714486862623        5.714487e+06
# 89     469  5346104406560        5.346104e+06
# 90     470  4599540212447        4.599540e+06
# 91     471  4666450628415        4.666451e+06
# 92     472  4670617133516        4.670617e+06
# 93     473  4639581179090        4.639581e+06
# 94     474  5376091844790        5.376092e+06
# 95     475  5367558752590        5.367559e+06
# 96     476  5390940673883        5.390941e+06
# 97     477  5688139319180        5.688139e+06
# 98     478  5691274859721        5.691275e+06
# 99     479  5656380725637        5.656381e+06
# 100    480  6082960424867        6.082960e+06
# 101    481  6715220194981        6.715220e+06
# 102    482  6752028201154        6.752028e+06
# 103    483  7027674682895        7.027675e+06
# 104    484  6944191907540        6.944192e+06
# 105    485  7081374505885        7.081375e+06
# 106    486  7120786993692        7.120787e+06
# 107    487  7091504384910        7.091504e+06
# 108    488  7122144228178        7.122144e+06
# 109    489  7198378284977        7.198378e+06
# 110    490  7248814041508        7.248814e+06
# 111    491  7232154966074        7.232155e+06
# 112    492  7315703365576        7.315703e+06
# 113    493  7254997325454        7.254997e+06
# 114    494  7299593586923        7.299594e+06
# 115    495  7326145921340        7.326146e+06
# 116    496  7322187047551        7.322187e+06
# 117    497  7654960475263        7.654960e+06
# 118    498  7743987666222        7.743988e+06
# 119    499  7669104313745        7.669104e+06
# 120    500  7590142010183        7.590142e+06
# 121    501  7897204362419        7.897204e+06
# 122    502  8089002636751        8.089003e+06
# 123    503  8100000398709        8.100000e+06
# 124    504  8082022688819        8.082023e+06
# 125    505  8137917765994        8.137918e+06

# %%
# =================================================Rewards=========================================

# %%
import calendar, time;
import os
import pandas as pd
import glob

# path: str = os.getcwd() + "\\INDY_Rewards"

# def func(value):
#     value1= pd.to_datetime("2022-11-27 21:45:00")
#     value2= value-value1
#     return value2
    
# if "Rewards" not in os.listdir(os.getcwd()):
#     os.mkdir(f"{os.getcwd()}\\Rewards")

# timestamps: list[int] = []

# for filename in os.listdir(path):
#     filename = filename.replace(".", "-")
#     fname: list[str] = filename.split("-")
#     timestamps.append(int(fname[-2]))

# for index, file in list(enumerate(os.listdir(path))):
#     df = pd.read_csv(f"{path}\\{file}")

#     df.to_csv(f"{os.getcwd()}\\Rewards\\{timestamps[index]}.csv")
# #     print(file)

# #Combining files
# path = "Rewards"

# csv_files = glob.glob(path + "/*.csv")

# # Read each CSV file into DataFrame
# # This creates a list of dataframes
# df_list = (pd.read_csv(file) for file in csv_files)

# # Concatenate all DataFrames
# reward_df   = pd.concat(df_list, ignore_index=True)
# reward_df=reward_df.drop("Unnamed: 0",axis=1)
# reward_df.insert(5, column="actual_amount", value=reward_df['amount']/1000000)
# indexAge = reward_df[ (reward_df['purpose'] != 'INDY staking reward') ].index
# reward_df.drop(indexAge , inplace=True)
# reward_df2=reward_df.drop(['addr','Expiration','AvailableAt','date','purpose'], axis=1)
# # reward_df2
# gk3=reward_df2.groupby('epoch').sum()
# # print(gk3.to_string())
# gk3


path: str = os.getcwd() + "\\INDY_Rewards"
    
excel_files = [file for file in os.listdir(path) if file.endswith('.xlsx')]
reward_df = pd.concat((pd.read_excel(os.path.join(path, file), engine='openpyxl') for file in excel_files), ignore_index=True)

columns_to_drop = ['addr','Expiration','AvailableAt']
reward_df = reward_df.drop(columns=columns_to_drop)
reward_df['amount']=reward_df['amount']/1000000


indexAge = reward_df[ (reward_df['purpose'] != 'INDY staking reward') ].index
reward_df.drop(indexAge , inplace=True)

reward_df=reward_df.groupby(['epoch','date','purpose'])


filtered_df1_month=reward_df.sum()
gk3 = filtered_df1_month.reset_index()
print(gk3.to_string())
# Out:
#     epoch       date              purpose       amount
# 0     452 2023-12-01  INDY staking reward  2398.000003
# 1     453 2023-12-06  INDY staking reward  2398.000008
# 2     454 2023-12-11  INDY staking reward  2398.000008
# 3     455 2023-12-16  INDY staking reward  2397.999984
# 4     456 2023-12-21  INDY staking reward  2398.000004
# 5     457 2023-12-26  INDY staking reward  2398.000005
# 6     458 2023-12-31  INDY staking reward  2397.999988
# 7     459 2024-01-05  INDY staking reward  2398.000008
# 8     460 2024-01-10  INDY staking reward  2397.999999
# 9     461 2024-01-15  INDY staking reward  2398.000002
# 10    462 2024-01-20  INDY staking reward  2397.999987
# 11    463 2024-01-25  INDY staking reward  2398.000002
# 12    464 2024-01-30  INDY staking reward  2398.000007
# 13    465 2024-02-04  INDY staking reward  2398.000001
# 14    466 2024-02-09  INDY staking reward  2398.000001
# 15    467 2024-02-14  INDY staking reward  2397.999988
# 16    468 2024-02-19  INDY staking reward  2397.999991
# 17    469 2024-02-24  INDY staking reward  2398.000014
# 18    470 2024-02-29  INDY staking reward  2397.999995
# 19    471 2024-03-05  INDY staking reward  2397.999999
# 20    472 2024-03-10  INDY staking reward  2398.000000
# 21    473 2024-03-15  INDY staking reward  2398.000005
# 22    474 2024-03-20  INDY staking reward  2398.000018
# 23    475 2024-03-25  INDY staking reward  2398.000003
# 24    476 2024-03-30  INDY staking reward  2397.999987
# 25    477 2024-04-04  INDY staking reward  2398.000000
# 26    478 2024-04-09  INDY staking reward  2398.000012
# 27    479 2024-04-14  INDY staking reward  2398.000006
# 28    480 2024-04-19  INDY staking reward  2397.999996
# 29    481 2024-04-24  INDY staking reward  2397.999991
# 30    482 2024-04-29  INDY staking reward  2398.000001
# 31    483 2024-05-04  INDY staking reward  2398.000012
# 32    484 2024-05-09  INDY staking reward  2398.000012
# 33    485 2024-05-14  INDY staking reward  2397.999989
# 34    486 2024-05-19  INDY staking reward  2398.000003
# 35    487 2024-05-24  INDY staking reward  2398.000000
# 36    488 2024-05-29  INDY staking reward  2397.999978
# 37    489 2024-06-03  INDY staking reward  6046.109994
# 38    490 2024-06-08  INDY staking reward  6046.109976
# 39    491 2024-06-13  INDY staking reward  6046.110001
# 40    492 2024-06-18  INDY staking reward  6046.110018
# 41    493 2024-06-23  INDY staking reward  6046.109994
# 42    494 2024-06-28  INDY staking reward  6046.110005
# 43    495 2024-07-03  INDY staking reward  6046.109987
# 44    496 2024-07-08  INDY staking reward  6046.109993
# 45    497 2024-07-13  INDY staking reward  6046.109999
# 46    498 2024-07-18  INDY staking reward  6046.109988
# 47    499 2024-07-23  INDY staking reward  6046.109995
# 48    500 2024-07-28  INDY staking reward  6046.110006
# 49    501 2024-08-02  INDY staking reward  6046.109998
# 50    502 2024-08-07  INDY staking reward  6046.110016
# 51    503 2024-08-12  INDY staking reward  6046.110001
# 52    504 2024-08-17  INDY staking reward  6046.110003
# 53    505 2024-08-22  INDY staking reward  6046.110007

# %%
# ==============================Calx for epoch-===================================================

# %%
# epoch

# r=2398
# index_list = gk3.index.tolist()
# # place1=dk.get_group(epoch) ############2
# # place1
# # gk3['epoch']
# gk3= gk3.reset_index()
# r_int = gk3[gk3['epoch'] == epoch]
# r=r_int.amount.tolist()[0]
# # r
# dk=dk.reset_index()
# s_int=dk[dk['epoch'] == epoch]
# s=s_int.Actual_INDY_Staked.tolist()[0]
# s
# APY = (r/s)*73*100
# print(APY)
# # (2398/5048280.848338)*7300

#rewards for epoch
# epoch1=[489,490,491,492,493,494]
epoch1=[505]#change this
APY3_arr=[]
running_sum1=0
gk3= gk3.reset_index()
dk= dk.reset_index()
for i in epoch1:
    print(i)
#     place13=gk.get_group((i,'INDY staking reward')).sum() ############2
#     r3=place13.amount
    r_int_month = gk3[gk3['epoch'] == i]
    r_int_month=r_int_month.amount.tolist()[0]
    print(r_int_month)
#     place23=dk.get_group(i).sum() ############2
#     s3=place23.Actual_INDY_Staked
#     running_sum1=running_sum+s2
#     print(running_sum)
    
    s_int_month = dk[dk['epoch'] == i]
    s_int_month=s_int_month.Actual_INDY_Staked.tolist()[0]
    print(s_int_month)
    
    
    
    inter = ((r_int_month/s_int_month)*73)
    print(inter)
#     APY3= ((1+(inter/73))**73-1)*100
# #     print(APY3)
    APY3_arr.append(inter*100)
print(APY3_arr)
print(sum(APY3_arr)/len(APY3_arr))


# ((2398*6)/)*73*100
# Out:
# 505
# 6046.110006999999
# 8137917.765994
# 0.05423574472026993
# [5.423574472026993]
# 5.423574472026993

# %%
# monthly

# r=2398
# index_list = gk3.index.tolist()
# # place1=dk.get_group(epoch) ############2
# # place1
# # gk3['epoch']
# gk3= gk3.reset_index()
# r_int = gk3[gk3['epoch'] == epoch]
# r=r_int.amount.tolist()[0]
# # r
# dk=dk.reset_index()
# s_int=dk[dk['epoch'] == epoch]
# s=s_int.Actual_INDY_Staked.tolist()[0]
# s
# APY = (r/s)*73*100
# print(APY)
# # (2398/5048280.848338)*7300

#rewards for epoch
# epoch1=[464]
epoch1=[495,496,497,498,499,500,501]#change this
APY3_arr=[]
running_sum1=0
gk3= gk3.reset_index()
dk= dk.reset_index()
for i in epoch1:
    print(i)
#     place13=gk.get_group((i,'INDY staking reward')).sum() ############2
#     r3=place13.amount
    r_int_month = gk3[gk3['epoch'] == i]
    r_int_month=r_int_month.amount.tolist()[0]
    print(r_int_month)
#     place23=dk.get_group(i).sum() ############2
#     s3=place23.Actual_INDY_Staked
#     running_sum1=running_sum+s2
#     print(running_sum)
    
    s_int_month = dk[dk['epoch'] == i]
    s_int_month=s_int_month.Actual_INDY_Staked.tolist()[0]
    print(s_int_month)
    
    
    
    inter = ((r_int_month/s_int_month)*73)
    print(inter)
#     APY3= ((1+(inter/73))**73-1)*100
# #     print(APY3)
    APY3_arr.append(inter*100)
print(APY3_arr)
print(sum(APY3_arr)/len(APY3_arr))


# ((2398*6)/)*73*100
# Out:
# 495
# 6046.109987
# 7326145.92134
# 0.06024532322859757
# 496
# 6046.109993
# 7322187.0475510005
# 0.06027789601968998
# 497
# 6046.109999
# 7654960.4752630005
# 0.057657519114994005
# 498
# 6046.109987999999
# 7743987.6662220005
# 0.05699467098187229
# 499
# 6046.109995
# 7669104.313745
# 0.05755118349922023
# 500
# 6046.110006
# 7590142.010183
# 0.05814990415803282
# 501
# 6046.109998
# 7897204.362419
# 0.0558888955633921
# [6.0245323228597565, 6.0277896019689985, 5.7657519114994, 5.699467098187229, 5.755118349922023, 5.8149904158032815, 5.588889556339209]
# 5.810934179511413

# %%
# =========================================profit sharing==========================================

# %%
import urllib.request
import pandas as pd
import json
import time
from datetime import datetime
from typing import Final
# open a connection to a URL using urllib
webUrl  = urllib.request.urlopen('https://analytics.indigoprotocol.io/api/distributions')

# read the data from the URL and print it
data = webUrl.read()
# print (data)

# byteData 
b1 = str(data, 'UTF-8')  
# print(b1)
type(b1)

json_object = json.loads(b1)
# print(type(json_object))

df = pd.DataFrame(json_object)

REF_DATE: Final[datetime] = datetime(2022, 11, 27)
EPOCH: Final[int] = 379

def get_difference(date: datetime) -> int:
    difference = date - REF_DATE

    return difference.days

def func(value):
    full_date = time.strftime("%d %b %Y", time.gmtime(value))
    date = pd.to_datetime(full_date)
    diff = get_difference(date)
    return 379+(diff//5)
    
arr=[]
for i in range(len(df)):
    arr.append(func(df.loc[i, "timestamp"]))
#     df.loc[i, 2] = 181
df.insert(2, column="epoch" , value=arr)
df.insert(3, column="actual_ada_distributed", value=df['ada_distributed']/1000000)
df
# df = df.astype({'indy_ada_price':'int'})
# print(df.dtypes)
columns_to_drop = ['indy_usd_price','ada_usd_price']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)
df

df['indy_ada_price'] = df['indy_ada_price'].astype(float)
df.insert(6, column="actual_value_in_INDY", value=df['actual_ada_distributed']/df['indy_ada_price'])
dk2=df.groupby('epoch')
dk22=dk2.sum()
dk23=dk22.tail(4)
print(dk23.to_string())
# Out:
#              slot  ada_distributed  actual_ada_distributed  indy_ada_price    timestamp  actual_value_in_INDY
# epoch
# 502    5251519268      24903007327            24903.007327       65.082879  68914170908          15122.054120
# 503    1975620217       1093906331             1093.906331       22.117574  25849114582            753.299030
# 504    1056706309      15877932111            15877.932111       11.556069  13789236637          11133.793116
# 505    1591806023        953874568              953.874568       18.259441  20690601515            629.702321

# %%
# epochs=[495,496,497,498,499,500,501]
epochs=[505]
# arr_epochs=dk.epoch.unique()
total=0
arr_profit_sharing=[]
# for i in arr_epochs:
for i in epochs:
    print(i)
    epo=dk2.get_group(i).sum()
    value=epo.actual_value_in_INDY
    total=total+value
    print(value)
    
#     staked=dk.get_group(i).sum() ############2
#     staked_value=staked.Actual_INDY_Staked
#     print(staked_value)
    
#     returns= ((value/staked_value)*73*100)
#     print(returns)

#     arr_profit_sharing.append(returns)
print(total)
# print(sum(arr_profit_sharing)/len(arr_profit_sharing))
# Out:
# 505
# 629.7023208816175
# 629.7023208816175

# %%
import urllib.request
import pandas as pd
import json
import time
from datetime import datetime
from typing import Final
# open a connection to a URL using urllib
webUrl  = urllib.request.urlopen('https://analytics.indigoprotocol.io/api/staking-manager/history?page=1&perPage=1000')

# read the data from the URL and print it
data = webUrl.read()
# print (data)

# byteData = b'Lets eat a \xf0\x9f\x8d\x95!'  
b1 = str(data, 'UTF-8')  
# print(b1)
type(b1)
json_object = json.loads(b1)
data_staking=json_object['data']
df_staking = pd.DataFrame(data_staking)
df_staking["date"] = df_staking["timestamp"].str.split("T").str[0]
df_staking["date"] = pd.to_datetime(df_staking["date"])
print(df_staking)



df_filtered_staking = df_staking.loc[(df_staking['date'] >= '2024-08-18')
                     &(df_staking['date'] <= '2024-08-22')]
print(df_filtered_staking)
answer=df_filtered_staking['totalStake'].sum()/5000000
print(answer)
print((total/answer)*73*100)
# Out:
#           slot     totalStake                    timestamp       date
# 0     77508385    27997627683  2022-11-21T23:52:05.000000Z 2022-11-21
# 1     77595292    57491824580  2022-11-22T23:59:43.000000Z 2022-11-22
# 2     77681705    94838510753  2022-11-23T23:59:56.000000Z 2022-11-23
# 3     77766658   108283961962  2022-11-24T23:35:49.000000Z 2022-11-24
# 4     77854394   122153855260  2022-11-25T23:58:05.000000Z 2022-11-25
# ..         ...            ...                          ...        ...
# 637  132540999  8687999112880  2024-08-19T22:41:30.000000Z 2024-08-19
# 638  132626959  8710832067135  2024-08-20T22:34:10.000000Z 2024-08-20
# 639  132713832  8720427831342  2024-08-21T22:42:03.000000Z 2024-08-21
# 640  132804234  8743770714694  2024-08-22T23:48:45.000000Z 2024-08-22
# 641  132819298  8685141944849  2024-08-23T03:59:49.000000Z 2024-08-23
#
# [642 rows x 4 columns]
#           slot     totalStake                    timestamp       date
# 636  132457047  8679524719516  2024-08-18T23:22:18.000000Z 2024-08-18
# 637  132540999  8687999112880  2024-08-19T22:41:30.000000Z 2024-08-19
# 638  132626959  8710832067135  2024-08-20T22:34:10.000000Z 2024-08-20
# 639  132713832  8720427831342  2024-08-21T22:42:03.000000Z 2024-08-21
# 640  132804234  8743770714694  2024-08-22T23:48:45.000000Z 2024-08-22
# 8708510.8891134
# 0.5278545323038351

# %%
((230000)/(7824167.6571502*1.95))*12*100
# Out:
# 18.089906523042753

# %%
#monthly
import urllib.request
import pandas as pd
import json
import time
from datetime import datetime
from typing import Final
# open a connection to a URL using urllib
webUrl  = urllib.request.urlopen('https://analytics.indigoprotocol.io/api/staking-manager/history?page=1&perPage=1000')

# read the data from the URL and print it
data = webUrl.read()
# print (data)

# byteData = b'Lets eat a \xf0\x9f\x8d\x95!'  
b1 = str(data, 'UTF-8')  
# print(b1)
type(b1)
json_object = json.loads(b1)
data_staking=json_object['data']
df_staking = pd.DataFrame(data_staking)
df_staking["date"] = df_staking["timestamp"].str.split("T").str[0]
df_staking["date"] = pd.to_datetime(df_staking["date"])
print(df_staking)



df_filtered_staking = df_staking.loc[(df_staking['date'] >= '2024-07-01')
                     &(df_staking['date'] <= '2024-08-02')]
print(df_filtered_staking)
answer=df_filtered_staking['totalStake'].sum()/(1000000*30)
print(answer)
print((total/answer)*12*100)
# Out:
#           slot     totalStake                    timestamp       date
# 0     77508385    27997627683  2022-11-21T23:52:05.000000Z 2022-11-21
# 1     77595292    57491824580  2022-11-22T23:59:43.000000Z 2022-11-22
# 2     77681705    94838510753  2022-11-23T23:59:56.000000Z 2022-11-23
# 3     77766658   108283961962  2022-11-24T23:35:49.000000Z 2022-11-24
# 4     77854394   122153855260  2022-11-25T23:58:05.000000Z 2022-11-25
# ..         ...            ...                          ...        ...
# 619  130989334  8440492083991  2024-08-01T23:40:25.000000Z 2024-08-01
# 620  131076407  8453251236674  2024-08-02T23:51:38.000000Z 2024-08-02
# 621  131159638  8474814094276  2024-08-03T22:58:49.000000Z 2024-08-03
# 622  131248710  8495565455171  2024-08-04T23:43:24.000000Z 2024-08-04
# 623  131255782  8495565455171  2024-08-05T01:41:13.000000Z 2024-08-05
#
# [624 rows x 4 columns]
#           slot     totalStake                    timestamp       date
# 588  128309641  7806108855615  2024-07-01T23:18:53.000000Z 2024-07-01
# 589  128393987  7833618570814  2024-07-02T22:44:38.000000Z 2024-07-02
# 590  128483576  7827343129195  2024-07-03T23:37:48.000000Z 2024-07-03
# 591  128571091  7837144842176  2024-07-04T23:56:23.000000Z 2024-07-04
# 592  128648099  7814115858045  2024-07-05T21:19:50.000000Z 2024-07-05
# 593  128743370  7820651976670  2024-07-06T23:47:41.000000Z 2024-07-06
# 594  128819722  7823559190947  2024-07-07T21:00:13.000000Z 2024-07-07
# 595  128916888  7825366417913  2024-07-08T23:59:39.000000Z 2024-07-08
# 596  129001547  7832495724113  2024-07-09T23:30:39.000000Z 2024-07-09
# 597  129088100  7846143110135  2024-07-10T23:33:12.000000Z 2024-07-10
# 598  129175710  8051470655840  2024-07-11T23:53:21.000000Z 2024-07-11
# 599  129258928  8058296736625  2024-07-12T23:00:19.000000Z 2024-07-12
# 600  129348557  8060521095070  2024-07-13T23:54:09.000000Z 2024-07-13
# 601  129428743  8082563210378  2024-07-14T22:10:34.000000Z 2024-07-14
# 602  129519333  8094682009639  2024-07-15T23:20:24.000000Z 2024-07-15
# 603  129604856  8142550865095  2024-07-16T23:05:47.000000Z 2024-07-16
# 604  129691902  8138386701714  2024-07-17T23:16:33.000000Z 2024-07-17
# 605  129780703  8146361177567  2024-07-18T23:56:34.000000Z 2024-07-18
# 606  129863063  8145967866451  2024-07-19T22:49:14.000000Z 2024-07-19
# 607  129952222  8146364371869  2024-07-20T23:35:13.000000Z 2024-07-20
# 608  130036245  8146909676269  2024-07-21T22:55:36.000000Z 2024-07-21
# 609  130119528  8164128695662  2024-07-22T22:03:39.000000Z 2024-07-22
# 610  130212327  8161495328927  2024-07-23T23:50:18.000000Z 2024-07-23
# 611  130297342  8163391311040  2024-07-24T23:27:14.000000Z 2024-07-24
# 612  130384417  8168318062818  2024-07-25T23:38:28.000000Z 2024-07-25
# 613  130468142  8175585082023  2024-07-26T22:53:53.000000Z 2024-07-26
# 614  130551123  8174090482418  2024-07-27T21:56:55.000000Z 2024-07-27
# 615  130644312  8179947451820  2024-07-28T23:50:03.000000Z 2024-07-28
# 616  130723761  8430450999158  2024-07-29T21:54:12.000000Z 2024-07-29
# 617  130814623  8443319839772  2024-07-30T23:08:35.000000Z 2024-07-30
# 618  130903991  8420610986592  2024-07-31T23:58:02.000000Z 2024-07-31
# 619  130989334  8440492083991  2024-08-01T23:40:25.000000Z 2024-08-01
# 620  131076407  8453251236674  2024-08-02T23:51:38.000000Z 2024-08-02
# 8895190.120101167
# 2.525609917267428

# %%
################no of INDY stakers

# %%
temp1=staking_df

filtered_temp1 = temp1.loc[(temp1['epoch'] >= 495)
                     & (temp1['epoch'] <= 501)]


temp_arr=filtered_temp1.owner.unique()
print(len(temp_arr))
# print(filtered_temp1.to_string())
# Out:
# 1428

# %%
import urllib.request
import pandas as pd
import json
import time
from datetime import datetime
from typing import Final
# open a connection to a URL using urllib
webUrl  = urllib.request.urlopen('https://analytics.indigoprotocol.io/api/distributions')

# read the data from the URL and print it
data = webUrl.read()
# print (data)

# byteData = b'Lets eat a \xf0\x9f\x8d\x95!'  
b1 = str(data, 'UTF-8')  
# print(b1)
type(b1)

json_object = json.loads(b1)
# print(type(json_object))

df = pd.DataFrame(json_object)

REF_DATE: Final[datetime] = datetime(2022, 11, 27)
EPOCH: Final[int] = 379

def get_difference(date: datetime) -> int:
    difference = date - REF_DATE

    return difference.days

def func(value):
    full_date = time.strftime("%d %b %Y", time.gmtime(value))
    date = pd.to_datetime(full_date)
    diff = get_difference(date)
    return 379+(diff//5)
    
arr=[]
for i in range(len(df)):
    arr.append(func(df.loc[i, "timestamp"]))
#     df.loc[i, 2] = 181
df.insert(2, column="epoch" , value=arr)
df.insert(3, column="actual_ada_distributed", value=df['ada_distributed']/1000000)
# df = df.astype({'indy_ada_price':'int'})
# print(df.dtypes)
df['indy_ada_price'] = df['indy_ada_price'].astype(float)
df.insert(8, column="actual_value", value=df['actual_ada_distributed']/df['indy_ada_price'])
df
dk2=df.groupby('epoch')
dk22=dk2.sum()
# print(dk22.to_string())
print(dk22.sum())
# Out:
# slot                                                           510803877125
# ada_distributed                                               2752980902362
# actual_ada_distributed                                       2752980.902362
# indy_usd_price            3.0655773.0655773.0655773.0655773.1322603.1322...
# indy_ada_price                                                 37243.088506
# ada_usd_price             0.3056750.3056760.3056760.3099500.3178830.3156...
# timestamp                                                     8680313648828
# actual_value                                                  479242.431406
# dtype: object

# %%
8.134135e+05-843.665901

# %%
print(dk22["actual_ada_distributed"].sum())

# %%
import os
import pandas as pd
import time
from datetime import datetime
from typing import Final
import glob

REF_DATE: Final[datetime] = datetime(2022, 11, 27)
EPOCH: Final[int] = 379

def get_difference(date: datetime) -> int:
    difference = date - REF_DATE

    return difference.days

path: str = os.getcwd() + "\\Staking_Data"
# path: str = os.getcwd() + "\\test"
print(path)

if "Staking_Data_Cleaned" not in os.listdir(os.getcwd()):
    os.mkdir(f"{os.getcwd()}\\Staking_Data_Cleaned")

timestamps: list[int] = []
days = []

for filename in os.listdir(path):
    if filename!='desktop.ini':
        
#     print(filename)
        filename = filename.replace(".", "-")
        fname: list[str] = filename.split("-")
        timestamps.append(int(fname[-2]))

for timestamp in timestamps:
    full_date = time.strftime("%d %b %Y", time.gmtime(timestamp))
    date = pd.to_datetime(full_date)
    diff = get_difference(date)
    days.append(diff)

for index, file in list(enumerate(os.listdir(path))):
    df = pd.read_csv(f"{path}\\{file}")

    df.insert(0, column="epoch", value= 379 + (days[index])//5 )
    df.to_csv(f"{os.getcwd()}\\Staking_Data_Cleaned\\{timestamps[index]}.csv")
#     print(file)

# # Get CSV files list from a folder
path1 = "Staking_Data_Cleaned"
csv_files = glob.glob(path1 + "/*.csv")

df_list1 = (pd.read_csv(file) for file in csv_files)

# Concatenate all DataFrames
staking_df   = pd.concat(df_list1, ignore_index=True)
staking_df.insert(4, column="Actual_INDY_Staked", value=staking_df['indy_staked']/1000000)
staking_df=staking_df.drop("Unnamed: 0",axis=1)
dk=staking_df.groupby('epoch')
dk1=dk.sum()
print(dk1.to_string())

# %%
import urllib.request
import pandas as pd
import json
import time
from datetime import datetime
from typing import Final
# open a connection to a URL using urllib
webUrl  = urllib.request.urlopen('https://analytics.indigoprotocol.io/api/staking-manager/history?page=1&perPage=1000')

# read the data from the URL and print it
data = webUrl.read()
# print (data)

# byteData = b'Lets eat a \xf0\x9f\x8d\x95!'  
b1 = str(data, 'UTF-8')  
# print(b1)
type(b1)
json_object = json.loads(b1)
data_staking=json_object['data']
df_staking = pd.DataFrame(data_staking)
df_staking["date"] = df_staking["timestamp"].str.split("T").str[0]
df_staking["date"] = pd.to_datetime(df_staking["date"])
print(df)



df_filtered_staking = df_staking.loc[(df_staking['date'] >= '2023-08-14')
                     &(df_staking['date'] <= '2023-08-18')]
print(df_filtered_staking)
answer=df_filtered_staking['totalStake'].sum()/5000000
print(answer)

# %%
def func(value):
    full_date = time.strftime("%d %b %Y", time.gmtime(value))
    date = pd.to_datetime(full_date)
    diff = get_difference(date)
    return 379+(diff//5)

print(func(1714467334))
# Out:
# 483
